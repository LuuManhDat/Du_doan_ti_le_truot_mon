# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/processed/student_processed.csv")

features = ["studytime","failures","absences","goout","Dalc","Walc"]

X = df[features]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
scores = []

for k in range(2,10):
    
    model = KMeans(n_clusters=k, random_state=42)
    labels = model.fit_predict(X_scaled)
    
    score = silhouette_score(X_scaled, labels)
    
    scores.append(score)

plt.plot(range(2,10), scores)
plt.title("Silhouette Score")
plt.show()

# %%
model = KMeans(n_clusters=3, random_state=42)

labels = model.fit_predict(X_scaled)

df["cluster"] = labels

df.head()
# Out:
#    school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 0       0    0   18        1        0        0     4     4     0     4  ...
# 1       0    0   17        1        0        1     1     1     0     2  ...
# 2       0    0   15        1        1        1     1     1     0     2  ...
# 3       0    0   15        1        0        1     4     2     1     3  ...
# 4       0    0   16        1        0        1     3     3     2     2  ...
#
#    goout  Dalc  Walc  health  absences  G1  G2  G3  pass  cluster
# 0      4     1     1       3         6   5   6   6     0        0
# 1      3     1     1       3         4   5   5   6     0        0
# 2      2     2     3       3        10   7   8  10     1        1
# 3      2     1     1       5         2  15  14  15     1        2
# 4      2     1     2       5         4   6  10  10     1        0
#
# [5 rows x 35 columns]
